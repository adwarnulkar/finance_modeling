# %% [markdown]
# # Expense Analyzer
#
# - Date : 01/02/2020
# - Author : Aditya Warnulkar (adwarnulkar@gmail.com)

# %%
expenses_file = 'expenses.xls' # Expense report from Toshl finance
budget_file = 'budget.csv' # Budget file as per your standard of living
salary = 6138 # Take home salary (After tax deduction)

# %%
import sys
import os
import re

import pandas as pd
import numpy as np

import itertools

import matplotlib.pyplot as plt
# %matplotlib inline

from bokeh.io import output_notebook , show
output_notebook()

from src import finance_post_process as fin
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df_expense = pd.read_excel(expenses_file,skiprows=1)
df_expense.head()
# Out:
#      Date Account       Category Tags  Amount Currency  In main currency  \
# 0  1/1/20    Cash        Grocery  NaN   19.98      USD             19.98
# 1  1/1/20    Cash       Shopping  NaN   10.12      USD             10.12
# 2  1/1/20    Cash  Food & Drinks  NaN   10.18      USD             10.18
# 3  1/2/20    Cash   Office Lunch  NaN   12.00      USD             12.00
# 4  1/3/20    Cash   Office Lunch  NaN   10.13      USD             10.13
#
#   Main currency             Description
# 0           USD  Miramar Cash and Carry
# 1           USD     Poor Economics Book
# 2           USD                Chipotle
# 3           USD             Kabul West
# 4           USD                  Rasraj

# %%
df_budget = pd.read_csv(budget_file)
df_budget.set_index('Category',inplace=True)

# %%
df_expense = df_expense.groupby('Category').sum()['Amount']

# %%
df_expense = pd.concat([df_budget,df_expense],axis=1,sort=False)
df_expense.fillna(0,inplace=True)
df_expense['leverage'] = df_expense['budget'] - df_expense['Amount']
df_expense['leverage_perc'] = 100 * df_expense['leverage'] / df_expense['budget']
df_expense = df_expense.replace([np.inf, -np.inf], np.nan)
df_expense.fillna(0,inplace=True)
df_expense
# Out:
#                   budget   Amount  leverage  leverage_perc
# Home & Utilities  1345.0  1315.22     29.78       2.214126
# Office Lunch       255.0   216.88     38.12      14.949020
# Grocery            250.0   208.36     41.64      16.656000
# Food & Drinks      200.0   107.56     92.44      46.220000
# Bills              150.0   248.00    -98.00     -65.333333
# Car                143.0   206.00    -63.00     -44.055944
# Shopping           100.0   103.72     -3.72      -3.720000
# Fuel                80.0    68.08     11.92      14.900000
# Gifts               50.0    21.97     28.03      56.060000
# Travel               0.0    17.42    -17.42       0.000000

# %%
print(f"Total Leverage : ${df_expense.leverage.sum():.2f}")
# Out:
# Total Leverage : $59.79

# %% [markdown]
# ## Plotting
# - https://docs.bokeh.org/en/latest/docs/user_guide/categorical.html

# %%
plt.figure(figsize=[10,10])
_ = plt.pie(df_expense.Amount,labels=df_expense.index,shadow=False, startangle=90,autopct='%1.1f%%')

# %%
show(fin.plot_expense(df_expense))
# Out:
#   <div class="bk-root" id="e4edfbfa-08f3-4a56-bf71-6d10fe405aea" data-root-id="1004"></div>

# %% [markdown]
# # Amount available for investment

# %%
salary_take_home = salary
salary_take_home
# Out:
# 6138

# %%
print(f"Total Leverage : ${df_expense.leverage.sum():.2f}")
# Out:
# Total Leverage : $59.79

# %%
storage = salary_take_home - df_expense.Amount.sum()
guilt_free_money = 0.1*storage
storage = storage - guilt_free_money
invest_perc = 100*storage/salary_take_home

print(f"Amount available for guilt free expenditure : ${guilt_free_money:.2f}")
print(f"Amount available for investment : ${storage:.2f} {invest_perc:.2f}%")
# Out:
# Amount available for guilt free expenditure : $362.48
# Amount available for investment : $3262.31 53.15%

# %%
df_goal = pd.read_csv("model_goal_allocation.csv",index_col='goal',usecols=['goal','model_investment'])
df_goal['asset_ratio'] = df_goal.model_investment / df_goal.model_investment.sum()
df_goal['actual_investment'] = df_goal.asset_ratio * storage
df_goal['delta'] = df_goal.actual_investment - df_goal.model_investment
df_goal
# Out:
#             model_investment  asset_ratio  actual_investment       delta
# goal
# home             1550.693801     0.507803        1656.610768  105.916967
# vacation          234.204323     0.076694         250.201170   15.996847
# wedding           377.733955     0.123696         403.534300   25.800345
# retirement        891.100000     0.291807         951.964762   60.864762

# %%
df_report = pd.concat([df_expense.Amount,df_goal.actual_investment])

# %%
df_report = df_report.append(pd.Series([guilt_free_money],index=['Guilt Free']))

# %%
df_report = df_report.to_frame(name='value')
df_report['percentage'] = 100*df_report.value/df_report.value.sum()
df_report
# Out:
#                         value  percentage
# Home & Utilities  1315.220000   21.427501
# Office Lunch       216.880000    3.533399
# Grocery            208.360000    3.394591
# Food & Drinks      107.560000    1.752362
# Bills              248.000000    4.040404
# Car                206.000000    3.356142
# Shopping           103.720000    1.689801
# Fuel                68.080000    1.109156
# Gifts               21.970000    0.357934
# Travel              17.420000    0.283806
# home              1656.610768   26.989423
# vacation           250.201170    4.076265
# wedding            403.534300    6.574361
# retirement         951.964762   15.509364
# Guilt Free         362.479000    5.905490

# %%
df_report.to_csv('report.csv')
